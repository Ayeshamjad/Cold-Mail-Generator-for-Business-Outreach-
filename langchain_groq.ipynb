# %%
# !pip install langchain_groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 5.5 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq (
    model = "llama-3.3-70b-versatile",
    temperature = 0,
    groq_api_key =''

)

response = llm.invoke("moon is..")
print(response.content)
# Out:
# The Moon is Earth's natural satellite, a rocky, airless body that orbits our planet. It's the fifth-largest moon in the solar system and is thought to have formed about 4.5 billion years ago, not long after the formation of the Earth. The Moon is in a synchronous rotation with Earth, which means it takes the Moon the same amount of time to rotate on its axis as it takes to orbit the Earth. This is why we see the same face of the Moon all the time. The Moon has no atmosphere, which means there's no wind, weather, or sound on its surface. It's a fascinating and complex world that has captivated human imagination for centuries. Would you like to know more about the Moon?

# %%
# !pip install chromadb

# %%
import chromadb

# %%
client = chromadb.Client()
collection = client.create_collection(name="my_collection")

# %%
collection.add(
    documents=["This is a document", "This is another document"],
    metadatas=[{"source": "my_source"}, {"source": "my_source"}],
    ids=["id1", "id2"]
)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:03<00:00, 21.4MiB/s]

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This is a document', 'This is another document'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'source': 'my_source'}, {'source': 'my_source'}]}

# %%
collection.query(
    query_texts=["This is a query document"],
    n_results=2
)
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This is a document', 'This is another document']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'source': 'my_source'}, {'source': 'my_source'}]],
#  'distances': [[0.7111214399337769, 1.0109773874282837]]}

# %% [markdown]
# llms

# %% [markdown]
# first extract job posting

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 32.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.3/423.3 kB 24.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.49
#     Uninstalling langchain-core-0.3.49:
#       Successfully uninstalled langchain-core-0.3.49
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.7
#     Uninstalling langchain-text-splitters-0.3.7:
#       Successfully uninstalled langchain-text-splitters-0.3.7
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.22
#     Uninstalling langchain-0.3.22:
#       Successfully uninstalled langchain-0.3.22
# ...

# %%
# !pip install streamlit

# %%
from langchain_community.document_loaders import WebBaseLoader
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader("https://careers.nike.com/accounting-administrative-assistant-san-marcos-premium-outlets/job/R-57818")

# %%
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Accounting/Administrative Assistant - San Marcos Premium Outlets
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
    """
    ### SCRAPED TEXT FROM WEBSITE:
    {page_data}
    ### INSTRUCTION:
    the scraped text is from careers page of a website, a job posting.
    your job is to extract the job postings and return them in JSON format containing the
    following keys: 'role','experience','skills' and 'description'.
    only return valid response.
    ### VALID JSON (NOPREAMBLE)
    """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke({"page_data": page_data})
print(res)
# Out:
# content='```json\n{\n  "role": "Accounting/Administrative Assistant",\n  "experience": "1 year of retail or consumer service experience",\n  "skills": [\n    "Proficient knowledge of office practices, procedures, and equipment",\n    "Intermediate skills in Microsoft Office products including Word and Excel",\n    "Ability to learn and train on the latest products and technologies",\n    "Ability to communicate in English",\n    "Strong customer service skills and the ability to exercise a high degree of professionalism",\n    "Strong attention to detail and deadlines"\n  ],\n  "description": "Administer advanced cashiering tasks, support scheduling, review associate tech functionality, perform standard cashiering duties, and resolve irregular or difficult transactions. The ideal candidate will have a strong customer service background, be proficient in Microsoft Office, and have the ability to work in a fast-paced environment."\n}\n```' additional_kwargs={} response_metadata={'token
# ...

# %%
type(res.content)
# Out:
# str

# %% [markdown]
# convert this txt into json object as this is in str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
print(json_res)
# Out:
# {'role': 'Accounting/Administrative Assistant', 'experience': '1 year of retail or consumer service experience', 'skills': ['Proficient knowledge of office practices, procedures, and equipment', 'Intermediate skills in Microsoft Office products including Word and Excel', 'Ability to learn and train on the latest products and technologies', 'Ability to communicate in English', 'Strong customer service skills and the ability to exercise a high degree of professionalism', 'Strong attention to detail and deadlines'], 'description': 'Administer advanced cashiering tasks, support scheduling, review associate tech functionality, perform standard cashiering duties, and resolve irregular or difficult transactions. The ideal candidate will have a strong customer service background, be proficient in Microsoft Office, and have the ability to work in a fast-paced environment.'}

# %%
type(json_res)
# Out:
# dict

# %% [markdown]
# import my data into chromadb

# %%
import pandas as pd
df = pd.read_csv('/content/my_portfolio.csv')

# %%
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import chromadb
client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

# %%
import uuid

# %%
if not collection.count():
  for _, row in df.iterrows():
    collection.add(documents=row["Techstack"],
                                 metadatas={"links":row["Links"]},
                                 ids = [str(uuid.uuid4())]
                                 )

# %%
links = collection.query(query_texts=["python"], n_results=5)

# %%
links
# Out:
# {'ids': [['99078f56-e53c-4d4f-a1b5-0bb1e7e59039',
#    '8e7d267b-5483-404d-8093-7c41ea6df0ce',
#    '07a5a612-7e88-4082-9640-480287e718fc',
#    '6737bc24-3b81-4bbd-afe2-de28db2f5db5',
#    '8a5fdb10-9bf4-4dc6-a164-4fc691ae67cf']],
#  'embeddings': None,
#  'documents': [['Machine Learning, Python, TensorFlow',
#    'Python, Django, MySQL',
#    'Magento, PHP, MySQL',
#    'WordPress, PHP, MySQL',
#    'iOS, Swift, ARKit']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'links': 'https://example.com/ml-python-portfolio'},
#    {'links': 'https://example.com/python-portfolio'},
#    {'links': 'https://example.com/magento-portfolio'},
#    {'links': 'https://example.com/wordpress-portfolio'},
#    {'links': 'https://example.com/ios-ar-portfolio'}]],
#  'distances': [[0.938150942325592,
#    1.0960942506790161,
#    1.5525996685028076,
#    1.5794390439987183,
#    1.6294276714324951]]}

# %%
job = json_res
job['skills']
# Out:
# ['Proficient knowledge of office practices, procedures, and equipment',
#  'Intermediate skills in Microsoft Office products including Word and Excel',
#  'Ability to learn and train on the latest products and technologies',
#  'Ability to communicate in English',
#  'Strong customer service skills and the ability to exercise a high degree of professionalism',
#  'Strong attention to detail and deadlines']

# %% [markdown]
# now we will create a prompt for email generation

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}

        ### INSTRUCTION:
        You are Ayesha, a business development executive. you work in an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools.
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability,
        process optimization, cost reduction, and heightened overall efficiency.
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of mu company
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase my company portfolio: {link_list}
        Remember you are Ayesha, BDE.
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):

        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Streamlining Accounting and Administrative Tasks with AI-Powered Solutions
#
# Dear Hiring Manager,
#
# I came across the job posting for an Accounting/Administrative Assistant and was impressed by the role's requirements, which align with our company's expertise in automating business processes. As a business development executive at an AI & Software Consulting company, I'd like to introduce you to our tailored solutions that can empower your organization to achieve scalability, process optimization, cost reduction, and heightened overall efficiency.
#
# Our company has a proven track record of delivering cutting-edge solutions that cater to various industries. Some of our notable projects include:
#
# * Machine Learning and Python-based solutions for predictive analytics and automation (https://example.com/ml-python-portfolio)
# * Customized Django and MySQL applications for streamlined data management (https://example.com/python-portfolio)
# ...
